# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("companies_sorted.csv")

# %%
data
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %%
company=pd.DataFrame(data)

# %%
company=company[pd.notnull(company['country'])]

# %%
company
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173420     1494425             inkredible printing
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %%
company.dropna()
# Out:
#          Unnamed: 0                                name              domain  \
# 0           5872184                                 ibm             ibm.com
# 1           4425416           tata consultancy services             tcs.com
# 2             21074                           accenture       accenture.com
# 3           2309813                             us army          goarmy.com
# 4           1558607                                  ey              ey.com
# ...             ...                                 ...                 ...
# 7173404     5101935                   squad sp. z o. o.        squad.com.pl
# 7173411     4768458  fuller, hadeed, & ros-planas, pllc          fhrlaw.com
# 7173416     3515286                     fit plus s.r.o.          fitplus.sk
# 7173417     5481997                          coriex srl           coriex.it
# 7173422     1494429              black tiger fight club  blacktigerclub.com
#
# ...

# %%
country = company['country'].value_counts(dropna=True, sort=False).nlargest(10)
country_freq = pd.DataFrame(country)
country_freq = country_freq.reset_index()
country_freq.columns = ['country', 'freq']
country_freq.sort_values(by=['freq'], inplace=True)
plt.xticks(rotation=90)
plt.yticks(np.arange(0, 10000000, 250000))
plt.title('Frequency of companies in countries') 
plt.xlabel('country') 
plt.ylabel('Frequency') 
plt.plot(country_freq['country'],country_freq['freq'],'r',linewidth=0.8)

# %%
country = company['country'].value_counts(dropna=True, sort=False).nlargest(10)
country_freq = pd.DataFrame(country)
country_freq = country_freq.reset_index()
country_freq.columns = ['country', 'freq']
country_freq.sort_values(by=['freq'], inplace=True)
plt.xticks(rotation=90)
plt.yticks(np.arange(0, 10000000, 150000))
plt.title('Frequency of companies in countries')
plt.xlabel('country') 
plt.ylabel('Frequency') 
plt.bar(country_freq['country'],country_freq['freq'],color = '#00BFFF')
# Out:
# <BarContainer object of 10 artists>

# %%
country = company['country'].value_counts(dropna=True, sort=False).nlargest(10)
country_freq = pd.DataFrame(country)
country_freq = country_freq.reset_index()
country_freq.columns = ['country', 'freq']
country_freq.sort_values(by=['freq'], inplace=True)
plt.rcParams['font.size'] = 10.0
plt.axis('equal')
plt.pie(country_freq['freq'], labels = country_freq['country'],autopct='%1.2f%%',wedgeprops={"edgecolor":"black"})
plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
plt.show()

# %%
country_freq['freq'].mean()
# Out:
# 386288.2

# %%
country_freq['freq'].median()
# Out:
# 140375.0

# %%
country_freq['freq'].var()
# Out:
# 456809064326.4001

# %%
country_freq['freq'].std()
# Out:
# 675876.5155902371

# %%
max=country_freq['freq'].max()
min=country_freq['freq'].min()
range=max-min
range
# Out:
# 2169048

# %%
employee_cnt = company['current employee estimate'].value_counts(dropna=True, sort=False)
employee_cnt
# Out:
# 0        950857
# 4098          2
# 1       1484304
# 4096          1
# 2        645397
#          ...
# 4087          2
# 4086          1
# 4089          1
# 4088          1
# 4095          1
# Name: current employee estimate, Length: 4997, dtype: int64

# %%
unwanted_zeroes_employee_cnt=company[company['current employee estimate'].astype(int)==0].index
unwanted_zeroes_employee_cnt
# Out:
# Int64Index([5710869, 5710871, 5710872, 5710873, 5710874, 5710875, 5710876,
#             5710878, 5710880, 5710882,
#             ...
#             7173413, 7173414, 7173415, 7173416, 7173417, 7173420, 7173422,
#             7173423, 7173424, 7173425],
#            dtype='int64', length=950857)

# %%
company.drop(unwanted_zeroes_employee_cnt, inplace=True)

# %%
# company=company[company['current employee estimate']>2]
# company
emp_company_est=company[company['current employee estimate']>2]
emp_company_est
# Out:
#          Unnamed: 0                       name                 domain  \
# 0           5872184                        ibm                ibm.com
# 1           4425416  tata consultancy services                tcs.com
# 2             21074                  accenture          accenture.com
# 3           2309813                    us army             goarmy.com
# 4           1558607                         ey                 ey.com
# ...             ...                        ...                    ...
# 2302035     7164268       premier door systems    premierdoors.com.au
# 2302037     5792652          la vista keno inc        lavistakeno.com
# 2302039     5875156          3creatives s.a.s.         3creatives.com
# 2302040     1975337              ombody health       ombodyhealth.com
# 2302041      195717       studio mario silvano  studiomariosilvano.it
#
#          year founded                             industry size range  \
# ...

# %%
employee_cnt = emp_company_est['current employee estimate'].value_counts(dropna=True, sort=False)
emp_cnt = pd.DataFrame(employee_cnt)
emp_cnt = emp_cnt.reset_index()
emp_cnt.columns = ['current employee estimate', 'freq']
emp_cnt.sort_values(by=['freq'], inplace=True)
emp_cnt=emp_cnt[emp_cnt['freq']>10000]
plt.xticks(rotation=90)
plt.title('Frequency of employee estimate across countries') 
plt.xlabel('current employee estimate') 
plt.ylabel('Frequency') 
plt.plot(emp_cnt['current employee estimate'],emp_cnt['freq'],'r',linewidth=0.8)

# %%
employee_cnt = emp_company_est['current employee estimate'].value_counts(dropna=True, sort=False).nlargest(20)
emp_cnt = pd.DataFrame(employee_cnt)
emp_cnt = emp_cnt.reset_index()
emp_cnt.columns = ['current employee estimate', 'freq']
emp_cnt.sort_values(by=['freq'], inplace=False)
emp_cnt=emp_cnt[emp_cnt['freq']>5000]
emp_cnt
# Out:
#     current employee estimate    freq
# 0                           3  348159
# 1                           4  222627
# 2                           5  156431
# 3                           6  117282
# 4                           7   91587
# 5                           8   73428
# 6                           9   60634
# 7                          10   50760
# 8                          11   43485
# 9                          12   37029
# 10                         13   32400
# 11                         14   28623
# 12                         15   25725
# 13                         16   22937
# 14                         17   20495
# 15                         18   18705
# 16                         19   17085
# 17                         20   15642
# 18                         21   14356
# 19                         22   13156

# %%
plt.xticks(rotation=90)
plt.xticks(np.arange(1, 100, 2))
plt.title('Frequency of employee estimate across countries') 
plt.xlabel('current employee estimate') 
plt.ylabel('Frequency') 
plt.bar(emp_cnt['current employee estimate'],emp_cnt['freq'],edgecolor="black",color = '#800080')
# Out:
# <BarContainer object of 20 artists>
